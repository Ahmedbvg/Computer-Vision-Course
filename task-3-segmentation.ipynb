# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

import cv2
from tqdm import tqdm_notebook, tnrange
from glob import glob
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf
from skimage.color import rgb2gray
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
#Set Parameters
im_width = 256
im_height = 256

# %%
train_files = []
mask_files = glob('../input/lgg-mri-segmentation/kaggle_3m/*/*_mask*')

for i in mask_files:
    train_files.append(i.replace('_mask',''))

print(train_files[:10])
print(mask_files[:10])
# Out:
# ['../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_56.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_8.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_34.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_33.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_43.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_39.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_7.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_31.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_6.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_38.tif']
# ['../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_56_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_8_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_34_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_33_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_43_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_39_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_7_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_31_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_6_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_38_mask.tif']

# %%
#Lets plot some samples
rows,cols=3,3
fig=plt.figure(figsize=(10,10))
for i in range(1,rows*cols+1):
    fig.add_subplot(rows,cols,i)
    img_path=train_files[i]
    msk_path=mask_files[i]
    img=cv2.imread(img_path)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    msk=cv2.imread(msk_path)
    plt.imshow(img)
    plt.imshow(msk,alpha=0.4)
plt.show()

# %%
df = pd.DataFrame(data={"filename": train_files, 'mask' : mask_files})
df_train, df_test = train_test_split(df,test_size = 0.1)
df_train, df_val = train_test_split(df_train,test_size = 0.2)
print(df_train.values.shape)
print(df_val.values.shape)
print(df_test.values.shape)
# Out:
# (2828, 2)
# (708, 2)
# (393, 2)

# %%
# From: https://github.com/zhixuhao/unet/blob/master/data.py
def train_generator(data_frame, batch_size, aug_dict,
        image_color_mode="rgb",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):
    '''
    can generate image and mask at the same time use the same seed for
    image_datagen and mask_datagen to ensure the transformation for image
    and mask is the same if you want to visualize the results of generator,
    set save_to_dir = "your path"
    '''
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col = "filename",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col = "mask",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %%
smooth=100

def dice_coef(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)
    And=K.sum(y_truef* y_predf)
    return((2* And + smooth) / (K.sum(y_truef) + K.sum(y_predf) + smooth))

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

def jac_distance(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)

    return - iou(y_true, y_pred)

# %%
def unet(input_size=(256,256,3)):
    inputs = Input(input_size)
    
    conv1 = Conv2D(64, (3, 3), padding='same')(inputs)
    bn1 = Activation('relu')(conv1)
    conv1 = Conv2D(64, (3, 3), padding='same')(bn1)
    bn1 = BatchNormalization(axis=3)(conv1)
    bn1 = Activation('relu')(bn1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(bn1)

    conv2 = Conv2D(128, (3, 3), padding='same')(pool1)
    bn2 = Activation('relu')(conv2)
    conv2 = Conv2D(128, (3, 3), padding='same')(bn2)
    bn2 = BatchNormalization(axis=3)(conv2)
    bn2 = Activation('relu')(bn2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(bn2)

    conv3 = Conv2D(256, (3, 3), padding='same')(pool2)
    bn3 = Activation('relu')(conv3)
    conv3 = Conv2D(256, (3, 3), padding='same')(bn3)
    bn3 = BatchNormalization(axis=3)(conv3)
    bn3 = Activation('relu')(bn3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(bn3)

    conv4 = Conv2D(512, (3, 3), padding='same')(pool3)
    bn4 = Activation('relu')(conv4)
    conv4 = Conv2D(512, (3, 3), padding='same')(bn4)
    bn4 = BatchNormalization(axis=3)(conv4)
    bn4 = Activation('relu')(bn4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(bn4)

    conv5 = Conv2D(1024, (3, 3), padding='same')(pool4)
    bn5 = Activation('relu')(conv5)
    conv5 = Conv2D(1024, (3, 3), padding='same')(bn5)
    bn5 = BatchNormalization(axis=3)(conv5)
    bn5 = Activation('relu')(bn5)

    up6 = concatenate([Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(bn5), conv4], axis=3)
    conv6 = Conv2D(512, (3, 3), padding='same')(up6)
    bn6 = Activation('relu')(conv6)
    conv6 = Conv2D(512, (3, 3), padding='same')(bn6)
    bn6 = BatchNormalization(axis=3)(conv6)
    bn6 = Activation('relu')(bn6)

    up7 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(bn6), conv3], axis=3)
    conv7 = Conv2D(256, (3, 3), padding='same')(up7)
    bn7 = Activation('relu')(conv7)
    conv7 = Conv2D(256, (3, 3), padding='same')(bn7)
    bn7 = BatchNormalization(axis=3)(conv7)
    bn7 = Activation('relu')(bn7)

    up8 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(bn7), conv2], axis=3)
    conv8 = Conv2D(128, (3, 3), padding='same')(up8)
    bn8 = Activation('relu')(conv8)
    conv8 = Conv2D(128, (3, 3), padding='same')(bn8)
    bn8 = BatchNormalization(axis=3)(conv8)
    bn8 = Activation('relu')(bn8)

    up9 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(bn8), conv1], axis=3)
    conv9 = Conv2D(64, (3, 3), padding='same')(up9)
    bn9 = Activation('relu')(conv9)
    conv9 = Conv2D(64, (3, 3), padding='same')(bn9)
    bn9 = BatchNormalization(axis=3)(conv9)
    bn9 = Activation('relu')(bn9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(bn9)

    return Model(inputs=[inputs], outputs=[conv10])

# %%
model = unet()
model.summary()
# Out:
# I0000 00:00:1765217530.325692      47 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 256, 256,  │          0 │ conv2d[0][0]      │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │     36,928 │ activation[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 128, 128,  │          0 │ conv2d_2[0][0]    │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │    147,584 │ activation_2[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 64, 64,    │          0 │ conv2d_4[0][0]    │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    590,080 │ activation_4[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 32, 32,    │          0 │ conv2d_6[0][0]    │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │  2,359,808 │ activation_6[0][… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │  4,719,616 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 16, 16,    │          0 │ conv2d_8[0][0]    │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │  9,438,208 │ activation_8[0][… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      4,096 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │  2,097,664 │ activation_9[0][… │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │  4,719,104 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 32, 32,    │          0 │ conv2d_10[0][0]   │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │  2,359,808 │ activation_10[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │    524,544 │ activation_11[0]… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │  1,179,904 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 64, 64,    │          0 │ conv2d_12[0][0]   │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │    590,080 │ activation_12[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │    131,200 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │    295,040 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 128, 128,  │          0 │ conv2d_14[0][0]   │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │    147,584 │ activation_14[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 256, 256,  │     32,832 │ activation_15[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │     73,792 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 256, 256,  │          0 │ conv2d_16[0][0]   │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │     36,928 │ activation_16[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │         65 │ activation_17[0]… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,043,521 (118.42 MB)
#  Trainable params: 31,037,633 (118.40 MB)
#  Non-trainable params: 5,888 (23.00 KB)

# %%
EPOCHS = 50
BATCH_SIZE = 32
learning_rate = 1e-4

# %%
train_generator_args = dict(
    rotation_range=0.2,
    width_shift_range=0.05,
    height_shift_range=0.05,
    shear_range=0.05,
    zoom_range=0.05,
    horizontal_flip=True,
    fill_mode='nearest'
)

train_gen = train_generator(
    df_train, BATCH_SIZE,
    train_generator_args,
    target_size=(im_height, im_width)
)

test_gen = train_generator(
    df_val, BATCH_SIZE,
    dict(),
    target_size=(im_height, im_width)
)

model = unet(input_size=(im_height, im_width, 3))

opt = Adam(
    learning_rate=learning_rate,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07
)

model.compile(
    optimizer=opt,
    loss=dice_coef_loss,
    metrics=["binary_accuracy", iou, dice_coef]
)

callbacks = [
    ModelCheckpoint(
        'unet_brain_mri_seg.keras',
        verbose=1,
        save_best_only=True
    )
]


history = model.fit(
    train_gen,
    steps_per_epoch=len(df_train) // BATCH_SIZE,
    epochs=EPOCHS,
    callbacks=callbacks,
    validation_data=test_gen,
    validation_steps=len(df_val) // BATCH_SIZE
)
# Out:
# Found 2828 validated image filenames.
# Found 2828 validated image filenames.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_236']
# Received: inputs=Tensor(shape=(None, 256, 256, 3))
#   warnings.warn(msg)
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 875ms/step - binary_accuracy: 0.7933 - dice_coef: 0.0710 - iou: 0.0374 - loss: -0.0710Found 708 validated image filenames.
# Found 708 validated image filenames.
#
# Epoch 1: val_loss improved from inf to -0.02047, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 104s 990ms/step - binary_accuracy: 0.7945 - dice_coef: 0.0714 - iou: 0.0376 - loss: -0.0714 - val_binary_accuracy: 0.9897 - val_dice_coef: 0.0205 - val_iou: 0.0104 - val_loss: -0.0205
# Epoch 2/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 884ms/step - binary_accuracy: 0.9804 - dice_coef: 0.1643 - iou: 0.0908 - loss: -0.1634
# Epoch 2: val_loss did not improve from -0.02047
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 89s 946ms/step - binary_accuracy: 0.9804 - dice_coef: 0.1644 - iou: 0.0909 - loss: -0.1636 - val_binary_accuracy: 0.9894 - val_dice_coef: 0.0202 - val_iou: 0.0103 - val_loss: -0.0202
# Epoch 3/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9864 - dice_coef: 0.1822 - iou: 0.1026 - loss: -0.1851
# Epoch 3: val_loss improved from -0.02047 to -0.10963, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 101s 1s/step - binary_accuracy: 0.9864 - dice_coef: 0.1825 - iou: 0.1029 - loss: -0.1854 - val_binary_accuracy: 0.9927 - val_dice_coef: 0.1073 - val_iou: 0.0575 - val_loss: -0.1096
# Epoch 4/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 857ms/step - binary_accuracy: 0.9864 - dice_coef: 0.2175 - iou: 0.1246 - loss: -0.2204
# Epoch 4: val_loss improved from -0.10963 to -0.17536, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 85s 967ms/step - binary_accuracy: 0.9864 - dice_coef: 0.2179 - iou: 0.1249 - loss: -0.2207 - val_binary_accuracy: 0.9906 - val_dice_coef: 0.1688 - val_iou: 0.0943 - val_loss: -0.1754
# Epoch 5/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 824ms/step - binary_accuracy: 0.9875 - dice_coef: 0.2578 - iou: 0.1519 - loss: -0.2587
# Epoch 5: val_loss did not improve from -0.17536
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 78s 885ms/step - binary_accuracy: 0.9876 - dice_coef: 0.2584 - iou: 0.1522 - loss: -0.2592 - val_binary_accuracy: 0.9927 - val_dice_coef: 0.1832 - val_iou: 0.1044 - val_loss: -0.1711
# Epoch 6/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 818ms/step - binary_accuracy: 0.9907 - dice_coef: 0.3120 - iou: 0.1904 - loss: -0.3147
# Epoch 6: val_loss improved from -0.17536 to -0.32382, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 79s 902ms/step - binary_accuracy: 0.9907 - dice_coef: 0.3126 - iou: 0.1908 - loss: -0.3152 - val_binary_accuracy: 0.9940 - val_dice_coef: 0.3117 - val_iou: 0.1903 - val_loss: -0.3238
# Epoch 7/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 810ms/step - binary_accuracy: 0.9918 - dice_coef: 0.3708 - iou: 0.2353 - loss: -0.3760
# Epoch 7: val_loss improved from -0.32382 to -0.45159, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 78s 893ms/step - binary_accuracy: 0.9918 - dice_coef: 0.3713 - iou: 0.2357 - loss: -0.3765 - val_binary_accuracy: 0.9929 - val_dice_coef: 0.4347 - val_iou: 0.2856 - val_loss: -0.4516
# Epoch 8/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 810ms/step - binary_accuracy: 0.9918 - dice_coef: 0.4170 - iou: 0.2731 - loss: -0.4242
# Epoch 8: val_loss did not improve from -0.45159
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 78s 890ms/step - binary_accuracy: 0.9918 - dice_coef: 0.4175 - iou: 0.2736 - loss: -0.4247 - val_binary_accuracy: 0.9942 - val_dice_coef: 0.3413 - val_iou: 0.2125 - val_loss: -0.3541
# Epoch 9/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 842ms/step - binary_accuracy: 0.9920 - dice_coef: 0.4409 - iou: 0.2959 - loss: -0.4468
# Epoch 9: val_loss improved from -0.45159 to -0.54451, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 81s 925ms/step - binary_accuracy: 0.9920 - dice_coef: 0.4417 - iou: 0.2965 - loss: -0.4475 - val_binary_accuracy: 0.9959 - val_dice_coef: 0.5420 - val_iou: 0.3761 - val_loss: -0.5445
# Epoch 10/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 930ms/step - binary_accuracy: 0.9935 - dice_coef: 0.5272 - iou: 0.3780 - loss: -0.5256
# Epoch 10: val_loss improved from -0.54451 to -0.57629, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - binary_accuracy: 0.9935 - dice_coef: 0.5279 - iou: 0.3786 - loss: -0.5263 - val_binary_accuracy: 0.9962 - val_dice_coef: 0.5797 - val_iou: 0.4140 - val_loss: -0.5763
# Epoch 11/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 878ms/step - binary_accuracy: 0.9942 - dice_coef: 0.5614 - iou: 0.4062 - loss: -0.5648
# Epoch 11: val_loss improved from -0.57629 to -0.63687, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 85s 965ms/step - binary_accuracy: 0.9942 - dice_coef: 0.5623 - iou: 0.4070 - loss: -0.5656 - val_binary_accuracy: 0.9962 - val_dice_coef: 0.6143 - val_iou: 0.4565 - val_loss: -0.6369
# Epoch 12/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 876ms/step - binary_accuracy: 0.9941 - dice_coef: 0.5668 - iou: 0.4208 - loss: -0.5731
# Epoch 12: val_loss improved from -0.63687 to -0.66263, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 84s 960ms/step - binary_accuracy: 0.9941 - dice_coef: 0.5676 - iou: 0.4216 - loss: -0.5739 - val_binary_accuracy: 0.9958 - val_dice_coef: 0.6511 - val_iou: 0.4922 - val_loss: -0.6626
# Epoch 13/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 879ms/step - binary_accuracy: 0.9944 - dice_coef: 0.6270 - iou: 0.4792 - loss: -0.6259
# Epoch 13: val_loss improved from -0.66263 to -0.67824, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 84s 962ms/step - binary_accuracy: 0.9944 - dice_coef: 0.6278 - iou: 0.4799 - loss: -0.6267 - val_binary_accuracy: 0.9967 - val_dice_coef: 0.6746 - val_iou: 0.5168 - val_loss: -0.6782
# Epoch 14/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 810ms/step - binary_accuracy: 0.9945 - dice_coef: 0.6621 - iou: 0.5195 - loss: -0.6593
# Epoch 14: val_loss improved from -0.67824 to -0.72029, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 78s 894ms/step - binary_accuracy: 0.9945 - dice_coef: 0.6627 - iou: 0.5201 - loss: -0.6599 - val_binary_accuracy: 0.9963 - val_dice_coef: 0.7237 - val_iou: 0.5730 - val_loss: -0.7203
# Epoch 15/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 773ms/step - binary_accuracy: 0.9948 - dice_coef: 0.6834 - iou: 0.5489 - loss: -0.6820
# Epoch 15: val_loss improved from -0.72029 to -0.77410, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 75s 858ms/step - binary_accuracy: 0.9948 - dice_coef: 0.6841 - iou: 0.5496 - loss: -0.6827 - val_binary_accuracy: 0.9973 - val_dice_coef: 0.7721 - val_iou: 0.6339 - val_loss: -0.7741
# Epoch 16/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 787ms/step - binary_accuracy: 0.9955 - dice_coef: 0.7185 - iou: 0.5838 - loss: -0.7170
# Epoch 16: val_loss did not improve from -0.77410
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 74s 848ms/step - binary_accuracy: 0.9955 - dice_coef: 0.7191 - iou: 0.5844 - loss: -0.7176 - val_binary_accuracy: 0.9971 - val_dice_coef: 0.7236 - val_iou: 0.5875 - val_loss: -0.7496
# Epoch 17/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 850ms/step - binary_accuracy: 0.9950 - dice_coef: 0.6961 - iou: 0.5677 - loss: -0.7017
# Epoch 17: val_loss improved from -0.77410 to -0.79061, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 82s 934ms/step - binary_accuracy: 0.9950 - dice_coef: 0.6970 - iou: 0.5686 - loss: -0.7025 - val_binary_accuracy: 0.9969 - val_dice_coef: 0.7968 - val_iou: 0.6668 - val_loss: -0.7906
# Epoch 18/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 788ms/step - binary_accuracy: 0.9961 - dice_coef: 0.7326 - iou: 0.5987 - loss: -0.7387
# Epoch 18: val_loss improved from -0.79061 to -0.81029, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 76s 871ms/step - binary_accuracy: 0.9961 - dice_coef: 0.7332 - iou: 0.5993 - loss: -0.7392 - val_binary_accuracy: 0.9974 - val_dice_coef: 0.7875 - val_iou: 0.6688 - val_loss: -0.8103
# Epoch 19/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 797ms/step - binary_accuracy: 0.9952 - dice_coef: 0.7389 - iou: 0.6133 - loss: -0.7379
# Epoch 19: val_loss improved from -0.81029 to -0.82103, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 77s 883ms/step - binary_accuracy: 0.9953 - dice_coef: 0.7396 - iou: 0.6140 - loss: -0.7385 - val_binary_accuracy: 0.9973 - val_dice_coef: 0.7988 - val_iou: 0.6854 - val_loss: -0.8210
# Epoch 20/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 792ms/step - binary_accuracy: 0.9961 - dice_coef: 0.7374 - iou: 0.6198 - loss: -0.7365
# Epoch 20: val_loss did not improve from -0.82103
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 75s 854ms/step - binary_accuracy: 0.9961 - dice_coef: 0.7382 - iou: 0.6207 - loss: -0.7374 - val_binary_accuracy: 0.9973 - val_dice_coef: 0.8056 - val_iou: 0.6787 - val_loss: -0.8135
# Epoch 21/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 831ms/step - binary_accuracy: 0.9956 - dice_coef: 0.7269 - iou: 0.6199 - loss: -0.7265
# Epoch 21: val_loss did not improve from -0.82103
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 78s 892ms/step - binary_accuracy: 0.9956 - dice_coef: 0.7278 - iou: 0.6207 - loss: -0.7274 - val_binary_accuracy: 0.9969 - val_dice_coef: 0.8208 - val_iou: 0.6992 - val_loss: -0.8196
# Epoch 22/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 841ms/step - binary_accuracy: 0.9954 - dice_coef: 0.7539 - iou: 0.6398 - loss: -0.7528
# Epoch 22: val_loss did not improve from -0.82103
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 79s 902ms/step - binary_accuracy: 0.9954 - dice_coef: 0.7546 - iou: 0.6404 - loss: -0.7535 - val_binary_accuracy: 0.9969 - val_dice_coef: 0.8165 - val_iou: 0.6926 - val_loss: -0.8144
# Epoch 23/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 860ms/step - binary_accuracy: 0.9949 - dice_coef: 0.7232 - iou: 0.6061 - loss: -0.7233
# Epoch 23: val_loss improved from -0.82103 to -0.83217, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 83s 944ms/step - binary_accuracy: 0.9949 - dice_coef: 0.7240 - iou: 0.6070 - loss: -0.7241 - val_binary_accuracy: 0.9974 - val_dice_coef: 0.8095 - val_iou: 0.6959 - val_loss: -0.8322
# Epoch 24/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 797ms/step - binary_accuracy: 0.9957 - dice_coef: 0.7744 - iou: 0.6586 - loss: -0.7737
# Epoch 24: val_loss did not improve from -0.83217
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 75s 858ms/step - binary_accuracy: 0.9957 - dice_coef: 0.7749 - iou: 0.6591 - loss: -0.7742 - val_binary_accuracy: 0.9962 - val_dice_coef: 0.7535 - val_iou: 0.6097 - val_loss: -0.7614
# Epoch 25/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 822ms/step - binary_accuracy: 0.9958 - dice_coef: 0.7710 - iou: 0.6609 - loss: -0.7701
# Epoch 25: val_loss improved from -0.83217 to -0.84478, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 79s 905ms/step - binary_accuracy: 0.9959 - dice_coef: 0.7717 - iou: 0.6616 - loss: -0.7708 - val_binary_accuracy: 0.9975 - val_dice_coef: 0.8143 - val_iou: 0.7104 - val_loss: -0.8448
# Epoch 26/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 806ms/step - binary_accuracy: 0.9955 - dice_coef: 0.7820 - iou: 0.6653 - loss: -0.7809
# Epoch 26: val_loss did not improve from -0.84478
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 76s 868ms/step - binary_accuracy: 0.9955 - dice_coef: 0.7826 - iou: 0.6660 - loss: -0.7815 - val_binary_accuracy: 0.9972 - val_dice_coef: 0.8127 - val_iou: 0.7089 - val_loss: -0.8438
# Epoch 27/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 816ms/step - binary_accuracy: 0.9961 - dice_coef: 0.7962 - iou: 0.6891 - loss: -0.7962
# Epoch 27: val_loss improved from -0.84478 to -0.85274, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 79s 900ms/step - binary_accuracy: 0.9961 - dice_coef: 0.7968 - iou: 0.6898 - loss: -0.7968 - val_binary_accuracy: 0.9974 - val_dice_coef: 0.8512 - val_iou: 0.7442 - val_loss: -0.8527
# Epoch 28/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 797ms/step - binary_accuracy: 0.9966 - dice_coef: 0.7661 - iou: 0.6571 - loss: -0.7657
# Epoch 28: val_loss improved from -0.85274 to -0.85865, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 77s 881ms/step - binary_accuracy: 0.9966 - dice_coef: 0.7669 - iou: 0.6580 - loss: -0.7665 - val_binary_accuracy: 0.9975 - val_dice_coef: 0.8587 - val_iou: 0.7552 - val_loss: -0.8587
# Epoch 29/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 788ms/step - binary_accuracy: 0.9953 - dice_coef: 0.7511 - iou: 0.6472 - loss: -0.7509
# Epoch 29: val_loss improved from -0.85865 to -0.85912, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 77s 872ms/step - binary_accuracy: 0.9953 - dice_coef: 0.7521 - iou: 0.6482 - loss: -0.7519 - val_binary_accuracy: 0.9976 - val_dice_coef: 0.8629 - val_iou: 0.7620 - val_loss: -0.8591
# Epoch 30/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 779ms/step - binary_accuracy: 0.9963 - dice_coef: 0.7745 - iou: 0.6668 - loss: -0.7744
# Epoch 30: val_loss did not improve from -0.85912
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 74s 841ms/step - binary_accuracy: 0.9963 - dice_coef: 0.7753 - iou: 0.6676 - loss: -0.7752 - val_binary_accuracy: 0.9976 - val_dice_coef: 0.8381 - val_iou: 0.7365 - val_loss: -0.8510
# Epoch 31/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - binary_accuracy: 0.9962 - dice_coef: 0.7796 - iou: 0.6795 - loss: -0.7787
# Epoch 31: val_loss improved from -0.85912 to -0.86586, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 78s 889ms/step - binary_accuracy: 0.9962 - dice_coef: 0.7804 - iou: 0.6803 - loss: -0.7795 - val_binary_accuracy: 0.9976 - val_dice_coef: 0.8658 - val_iou: 0.7653 - val_loss: -0.8659
# Epoch 32/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 957ms/step - binary_accuracy: 0.9956 - dice_coef: 0.7530 - iou: 0.6485 - loss: -0.7573
# Epoch 32: val_loss did not improve from -0.86586
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - binary_accuracy: 0.9956 - dice_coef: 0.7539 - iou: 0.6496 - loss: -0.7582 - val_binary_accuracy: 0.9976 - val_dice_coef: 0.8513 - val_iou: 0.7452 - val_loss: -0.8529
# Epoch 33/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 999ms/step - binary_accuracy: 0.9955 - dice_coef: 0.7529 - iou: 0.6533 - loss: -0.7522
# Epoch 33: val_loss did not improve from -0.86586
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - binary_accuracy: 0.9955 - dice_coef: 0.7539 - iou: 0.6544 - loss: -0.7532 - val_binary_accuracy: 0.9974 - val_dice_coef: 0.8505 - val_iou: 0.7534 - val_loss: -0.8615
# Epoch 34/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 988ms/step - binary_accuracy: 0.9955 - dice_coef: 0.7485 - iou: 0.6500 - loss: -0.7477
# Epoch 34: val_loss did not improve from -0.86586
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - binary_accuracy: 0.9955 - dice_coef: 0.7494 - iou: 0.6509 - loss: -0.7487 - val_binary_accuracy: 0.9971 - val_dice_coef: 0.8178 - val_iou: 0.7030 - val_loss: -0.8238
# Epoch 35/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 926ms/step - binary_accuracy: 0.9950 - dice_coef: 0.7641 - iou: 0.6615 - loss: -0.7638
# Epoch 35: val_loss improved from -0.86586 to -0.87387, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - binary_accuracy: 0.9950 - dice_coef: 0.7651 - iou: 0.6626 - loss: -0.7648 - val_binary_accuracy: 0.9977 - val_dice_coef: 0.8744 - val_iou: 0.7788 - val_loss: -0.8739
# Epoch 36/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 863ms/step - binary_accuracy: 0.9961 - dice_coef: 0.7915 - iou: 0.6824 - loss: -0.7915
# Epoch 36: val_loss did not improve from -0.87387
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 81s 927ms/step - binary_accuracy: 0.9961 - dice_coef: 0.7921 - iou: 0.6832 - loss: -0.7922 - val_binary_accuracy: 0.9973 - val_dice_coef: 0.8690 - val_iou: 0.7708 - val_loss: -0.8658
# Epoch 37/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 842ms/step - binary_accuracy: 0.9959 - dice_coef: 0.7684 - iou: 0.6702 - loss: -0.7683
# Epoch 37: val_loss did not improve from -0.87387
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 79s 903ms/step - binary_accuracy: 0.9959 - dice_coef: 0.7693 - iou: 0.6712 - loss: -0.7692 - val_binary_accuracy: 0.9977 - val_dice_coef: 0.8655 - val_iou: 0.7692 - val_loss: -0.8709
# Epoch 38/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 878ms/step - binary_accuracy: 0.9963 - dice_coef: 0.7999 - iou: 0.7015 - loss: -0.7996
# Epoch 38: val_loss did not improve from -0.87387
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 83s 946ms/step - binary_accuracy: 0.9963 - dice_coef: 0.8005 - iou: 0.7022 - loss: -0.8002 - val_binary_accuracy: 0.9967 - val_dice_coef: 0.8496 - val_iou: 0.7409 - val_loss: -0.8478
# Epoch 39/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 847ms/step - binary_accuracy: 0.9951 - dice_coef: 0.7416 - iou: 0.6379 - loss: -0.7418
# Epoch 39: val_loss did not improve from -0.87387
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 80s 908ms/step - binary_accuracy: 0.9951 - dice_coef: 0.7428 - iou: 0.6392 - loss: -0.7430 - val_binary_accuracy: 0.9977 - val_dice_coef: 0.8648 - val_iou: 0.7722 - val_loss: -0.8716
# Epoch 40/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 845ms/step - binary_accuracy: 0.9961 - dice_coef: 0.7559 - iou: 0.6553 - loss: -0.7554
# Epoch 40: val_loss did not improve from -0.87387
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 80s 907ms/step - binary_accuracy: 0.9961 - dice_coef: 0.7570 - iou: 0.6566 - loss: -0.7565 - val_binary_accuracy: 0.9976 - val_dice_coef: 0.8738 - val_iou: 0.7784 - val_loss: -0.8716
# Epoch 41/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 811ms/step - binary_accuracy: 0.9958 - dice_coef: 0.7885 - iou: 0.6945 - loss: -0.7883
# Epoch 41: val_loss did not improve from -0.87387
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 77s 872ms/step - binary_accuracy: 0.9959 - dice_coef: 0.7893 - iou: 0.6954 - loss: -0.7891 - val_binary_accuracy: 0.9970 - val_dice_coef: 0.8363 - val_iou: 0.7272 - val_loss: -0.8506
# Epoch 42/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 841ms/step - binary_accuracy: 0.9959 - dice_coef: 0.8000 - iou: 0.6999 - loss: -0.7999
# Epoch 42: val_loss improved from -0.87387 to -0.87731, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 81s 925ms/step - binary_accuracy: 0.9959 - dice_coef: 0.8007 - iou: 0.7008 - loss: -0.8006 - val_binary_accuracy: 0.9974 - val_dice_coef: 0.8676 - val_iou: 0.7710 - val_loss: -0.8773
# Epoch 43/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 789ms/step - binary_accuracy: 0.9963 - dice_coef: 0.7887 - iou: 0.6937 - loss: -0.7887
# Epoch 43: val_loss did not improve from -0.87731
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 75s 851ms/step - binary_accuracy: 0.9963 - dice_coef: 0.7895 - iou: 0.6944 - loss: -0.7894 - val_binary_accuracy: 0.9965 - val_dice_coef: 0.7541 - val_iou: 0.6316 - val_loss: -0.7787
# Epoch 44/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 833ms/step - binary_accuracy: 0.9956 - dice_coef: 0.7763 - iou: 0.6751 - loss: -0.7758
# Epoch 44: val_loss did not improve from -0.87731
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 79s 894ms/step - binary_accuracy: 0.9956 - dice_coef: 0.7771 - iou: 0.6761 - loss: -0.7767 - val_binary_accuracy: 0.9976 - val_dice_coef: 0.8713 - val_iou: 0.7815 - val_loss: -0.8763
# Epoch 45/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 844ms/step - binary_accuracy: 0.9959 - dice_coef: 0.7858 - iou: 0.6840 - loss: -0.7854
# Epoch 45: val_loss did not improve from -0.87731
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 79s 905ms/step - binary_accuracy: 0.9959 - dice_coef: 0.7866 - iou: 0.6850 - loss: -0.7862 - val_binary_accuracy: 0.9977 - val_dice_coef: 0.8667 - val_iou: 0.7750 - val_loss: -0.8702
# Epoch 46/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 817ms/step - binary_accuracy: 0.9962 - dice_coef: 0.7971 - iou: 0.6949 - loss: -0.7972
# Epoch 46: val_loss did not improve from -0.87731
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 77s 878ms/step - binary_accuracy: 0.9962 - dice_coef: 0.7978 - iou: 0.6957 - loss: -0.7979 - val_binary_accuracy: 0.9976 - val_dice_coef: 0.8624 - val_iou: 0.7637 - val_loss: -0.8725
# Epoch 47/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 831ms/step - binary_accuracy: 0.9964 - dice_coef: 0.8107 - iou: 0.7191 - loss: -0.8103
# Epoch 47: val_loss improved from -0.87731 to -0.88480, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 80s 914ms/step - binary_accuracy: 0.9964 - dice_coef: 0.8114 - iou: 0.7199 - loss: -0.8110 - val_binary_accuracy: 0.9978 - val_dice_coef: 0.8878 - val_iou: 0.8013 - val_loss: -0.8848
# Epoch 48/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 831ms/step - binary_accuracy: 0.9951 - dice_coef: 0.7806 - iou: 0.6927 - loss: -0.7804
# Epoch 48: val_loss did not improve from -0.88480
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 78s 892ms/step - binary_accuracy: 0.9951 - dice_coef: 0.7814 - iou: 0.6936 - loss: -0.7812 - val_binary_accuracy: 0.9969 - val_dice_coef: 0.8321 - val_iou: 0.7233 - val_loss: -0.8411
# Epoch 49/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 873ms/step - binary_accuracy: 0.9956 - dice_coef: 0.7857 - iou: 0.6879 - loss: -0.7854
# Epoch 49: val_loss did not improve from -0.88480
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 82s 936ms/step - binary_accuracy: 0.9956 - dice_coef: 0.7865 - iou: 0.6887 - loss: -0.7861 - val_binary_accuracy: 0.9974 - val_dice_coef: 0.8446 - val_iou: 0.7401 - val_loss: -0.8554
# Epoch 50/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 884ms/step - binary_accuracy: 0.9958 - dice_coef: 0.7793 - iou: 0.6780 - loss: -0.7789
# Epoch 50: val_loss did not improve from -0.88480
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 83s 944ms/step - binary_accuracy: 0.9958 - dice_coef: 0.7800 - iou: 0.6788 - loss: -0.7797 - val_binary_accuracy: 0.9972 - val_dice_coef: 0.8437 - val_iou: 0.7403 - val_loss: -0.8442

# %%
# Load model
model = load_model("unet_brain_mri_seg.keras", compile=False)

# Pick a test image
test_img_path = df_test["filename"].values[0]
img = cv2.imread(test_img_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_resized = cv2.resize(img_rgb, (256, 256))

# Normalize
input_img = img_resized / 255.0
input_img = np.expand_dims(input_img, axis=0)

# Predict mask
pred_mask = model.predict(input_img)[0]
pred_mask = (pred_mask > 0.5).astype(np.uint8)  # threshold to binary
pred_mask = pred_mask[:, :, 0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
# Resize mask back to original size
mask_original_size = cv2.resize(pred_mask, (img_rgb.shape[1], img_rgb.shape[0]))

# Find contours
contours, _ = cv2.findContours(mask_original_size, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Draw bounding boxes
img_box = img_rgb.copy()

for cnt in contours:
    if cv2.contourArea(cnt) > 50:  # ignore tiny noise
        x, y, w, h = cv2.boundingRect(cnt)
        cv2.rectangle(img_box, (x, y), (x+w, y+h), (255, 0, 0), 3)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(img_box)
plt.title("Tumor Bounding Box")
plt.axis("off")
plt.show()

# %%
plt.imshow(img_rgb)
plt.title("Original Image")
plt.axis("off")
plt.show()

# %%
plt.imshow(pred_mask, cmap='gray')
plt.title("Predicted Mask (binary)")
plt.axis("off")
plt.show()

# %%
for i in range(30):
    index = np.random.randint(1, len(df_test.index))

    # ---- Load & preprocess image ----
    img_path = df_test['filename'].iloc[index]
    mask_path = df_test['mask'].iloc[index]

    img = cv2.imread(img_path)
    img_resized = cv2.resize(img, (im_width, im_height))
    img_norm = img_resized / 255.0
    input_img = img_norm[np.newaxis, :, :, :]

    # ---- Prediction ----
    pred = model.predict(input_img)[0]
    pred_mask = (pred.squeeze() > 0.5).astype(np.uint8) * 255  # binary mask

    # ---- Find bounding box from mask ----
    contours, _ = cv2.findContours(pred_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    img_box = img_resized.copy()

    if len(contours) > 0:
        # take the biggest contour
        cnt = max(contours, key=cv2.contourArea)
        x, y, w, h = cv2.boundingRect(cnt)

        # draw bounding box
        cv2.rectangle(img_box, (x, y), (x + w, y + h), (0, 255, 0), 2)

    # ---- Plot results ----
    plt.figure(figsize=(14, 14))

    plt.subplot(1, 4, 1)
    plt.imshow(cv2.cvtColor(img_resized, cv2.COLOR_BGR2RGB))
    plt.title("Original Image")
    plt.axis("off")

    plt.subplot(1, 4, 2)
    true_mask = cv2.imread(mask_path, 0)
    true_mask = cv2.resize(true_mask, (im_width, im_height))
    plt.imshow(true_mask, cmap='gray')
    plt.title("True Mask")
    plt.axis("off")

    plt.subplot(1, 4, 3)
    plt.imshow(pred_mask, cmap='gray')
    plt.title("Predicted Mask")
    plt.axis("off")

    plt.subplot(1, 4, 4)
    plt.imshow(cv2.cvtColor(img_box, cv2.COLOR_BGR2RGB))
    plt.title("Prediction + Bounding Box")
    plt.axis("off")

    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_47/2934954295.py in <cell line: 0>()
#      53     plt.axis("off")
#      54
# ---> 55     plt.show()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     444     """
#     445     _warn_if_gui_out_of_main_thread()
# --> 446     return _get_backend_mod().show(*args, **kwargs)
#     447
#     448
#
# /usr/local/lib/python3.11/dist-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2344             if bbox_inches:
#    2345                 if bbox_inches == "tight":
# -> 2346                     bbox_inches = self.figure.get_tightbbox(
#    2347                         renderer, bbox_extra_artists=bbox_extra_artists)
#    2348                     if pad_inches is None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    1774
#    1775         for a in artists:
# -> 1776             bbox = a.get_tightbbox(renderer)
#    1777             if bbox is not None:
#    1778                 bb.append(bbox)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4386                 if ba:
#    4387                     bb.append(ba)
# -> 4388         self._update_title_position(renderer)
#    4389         axbbox = self.get_window_extent(renderer)
#    4390         bb.append(axbbox)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py in _update_title_position(self, renderer)
#    2970                 top = max(top, bb.ymax)
#    2971                 if title.get_text():
# -> 2972                     ax.yaxis.get_tightbbox(renderer)  # update offsetText
#    2973                     if ax.yaxis.offsetText.get_text():
#    2974                         bb = ax.yaxis.offsetText.get_tightbbox(renderer)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1323         ticks_to_draw = self._update_ticks()
#    1324
# -> 1325         self._update_label_position(renderer)
#    1326
#    1327         # go back to just this axis's tick labels
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2563         # get bounding boxes for this axis and any siblings
#    2564         # that have been set by `fig.align_ylabels()`
# -> 2565         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2566         x, y = self.label.get_position()
#    2567         if self.label_position == 'left':
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in _get_tick_boxes_siblings(self, renderer)
#    2098             axis = getattr(ax, f"{axis_name}axis")
#    2099             ticks_to_draw = axis._update_ticks()
# -> 2100             tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2101             bboxes.extend(tlb)
#    2102             bboxes2.extend(tlb2)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in _get_ticklabel_bboxes(self, ticks, renderer)
#    1302         if renderer is None:
#    1303             renderer = self.figure._get_renderer()
# -> 1304         return ([tick.label1.get_window_extent(renderer)
#    1305                  for tick in ticks if tick.label1.get_visible()],
#    1306                 [tick.label2.get_window_extent(renderer)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in <listcomp>(.0)
#    1302         if renderer is None:
#    1303             renderer = self.figure._get_renderer()
# -> 1304         return ([tick.label1.get_window_extent(renderer)
#    1305                  for tick in ticks if tick.label1.get_visible()],
#    1306                 [tick.label2.get_window_extent(renderer)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     959             bbox, info, descent = self._get_layout(self._renderer)
#     960             x, y = self.get_unitless_position()
# --> 961             x, y = self.get_transform().transform((x, y))
#     962             bbox = bbox.translated(x, y)
#     963             return bbox
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/transforms.py in transform(self, values)
#    1496
#    1497         # Transform the values
# -> 1498         res = self.transform_affine(self.transform_non_affine(values))
#    1499
#    1500         # Convert the result back to the shape of the input values.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/transforms.py in transform_affine(self, points)
#    2421     def transform_affine(self, points):
#    2422         # docstring inherited
# -> 2423         return self.get_affine().transform(points)
#    2424
#    2425     def transform_non_affine(self, points):
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/transforms.py in get_affine(self)
#    2447             return self._b.get_affine()
#    2448         else:
# -> 2449             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2450                                    self._a.get_affine().get_matrix()))
#    2451
#
# KeyboardInterrupt:
